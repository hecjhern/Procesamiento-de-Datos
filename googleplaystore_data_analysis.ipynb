# %% [markdown]
# <a href="https://colab.research.google.com/github/hecjhern/Procesamiento-de-Datos/blob/main/googleplaystore_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
import os

# %% [markdown]
# ### Loading the Dataset

# %%
google=pd.read_csv('/content/drive/MyDrive/Procesamiento de Datos/Practica 1/googleplaystore.csv', encoding= 'unicode_escape')

# %% [markdown]
# #### First 10 values

# %%
google.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
google.shape
# Out:
# (10841, 13)

# %% [markdown]
# #### Print the name of columns

# %%
google.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# #### Check for NULL Values

# %%
google.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# #### Check unique values

# %%
google.nunique()
# Out:
# App               9660
# Category            33
# Rating              39
# Reviews           6001
# Size               461
# Installs            21
# Type                 2
# Price               92
# Content Rating       6
# Genres             119
# Last Updated      1377
# Current Ver       2783
# Android Ver         33
# dtype: int64

# %% [markdown]
# #### Check for Duplicate values

# %%
google.duplicated().sum()
# Out:
# 483

# %% [markdown]
# No duplicate values present.

# %% [markdown]
# #### Make a copy of the dataset

# %%
df = google.copy()

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# #### Drop NULL values

# %%
df=df.dropna()
df.shape
# Out:
# (9360, 13)

# %% [markdown]
# #### Print first 10 values

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# #### Convert Date Time format

# %%
df["date_updated"] = pd.to_datetime(df['Last Updated'])
df['day_updated'] = df['date_updated'].dt.day
df['year_updated'] = df['date_updated'].dt.year
df['month_updated']=df['date_updated'].dt.month
df['year_updated'].astype(int);
df['day_updated'].astype(int);

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Type: Movie and TV Shows

# %%
sns.countplot(google['Type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Type')

# %% [markdown]
# ### Rating of shows and movies

# %%
sns.countplot(google['Content Rating'])
sns.countplot(google['Content Rating']).set_xticklabels(sns.countplot(google['Content Rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Content Rating')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Relation between Type and Rating

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Content Rating',hue='Type',data=google)
plt.title('Relation between Type and Content Rating')
plt.show()

# %% [markdown]
# ### Pie-chart for the Type: Movie and TV Shows

# %%
labels = ['Free', 'Paid']
size = google['Type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# ### Pie-chart for Rating

# %%
google['Content Rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud

# %% [markdown]
# ## Country

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.Category))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()

# %% [markdown]
# ## Cast in the Shows

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.Genres))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('cast.png')
plt.show()
